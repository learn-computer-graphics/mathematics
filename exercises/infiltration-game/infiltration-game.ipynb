# %% [markdown]
# # Infiltration Game
#
# > A small game where we will play with vectors and collisions
#
# ## Overview of the game
#
# We have a character which needs to reach the end of the map without being seing by the guards.
#
# ## I - Line  of sight
#
# TODO create a line with two dots. Mouse pos is a circle with a radius. When the mouse crosses the line, we detect it

# %%
from IPython.display import IFrame
IFrame("01-collision.html", width=800, height=650)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="01-collision.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
